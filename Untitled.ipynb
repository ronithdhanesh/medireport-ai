# %%
from pdf2image import convert_from_path
import cv2
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
POPPLER_PATH = r'C:\Program Files\poppler-24.08.0\Library\bin'
import numpy as np

# %%
images = convert_from_path('Blood report.pdf',poppler_path=POPPLER_PATH)

# %%
all_text = ""

# %%
for page_num, image in enumerate(images, start=1):
    image_cv = np.array(image)
    image_cv = cv2.cvtColor(image_cv, cv2.COLOR_RGB2BGR)
    
    gray = cv2.cvtColor(image_cv, cv2.COLOR_BGR2GRAY)
    gray = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]
    
    text = pytesseract.image_to_string(gray)
    all_text += f"\n\n-----{page_num}---\n\n {text}"

# %%
print(all_text)
# Out:
# -----1---
#
#  Kingdom of Bahrain dugg 4ste
# Minlstry of Heatth , 5 dasall By
# Primary Health Core QUA Asal Ato yt
# gent Centers Directorate Ayal SE jal Bal
# Laboratory Services PP prt eur Nee) 1
# NAME : DHANESH VANIYAM VEETIL PAVITHRAN
# CPRNUMBER _ : 680126554 REQUEST DATE: 25/03/2025 (18:35)
# DATE OF BIRTH ;: 18/01/1968 PHYSICIAN : () MOHAMED ABU ALQASSIM
# AGE/GENDER —: 57 Years /MALE REQUEST REASON : HTN AND OLP
# NATIONALITY —: Indian LOCATION : GP COVERAGE (BKHPRIGPC)
# CENTRE : BBK HIDD HC (BKH) ORIGIN : BBK HIOD HC
# LAB ID 225390019332 VALIDATION DATE _ ; 14/05/2025 (08:03)
# DIAGNOSIS
# Test Result Unit Flag__ REF. RANGES
# BIOCHEMISTRY
# THYROID STIMULATING HORMONE 1.02 mU/L 0.25-5
# 0.25-5 (EUTHYROIO) (ADULT)
# 0.0-0.25 (HYPERTHYROID) (ADULT)
# >5 (HYPOTHYROID) (ADULT)
# 1.0-15.2(1-6 DAYS)
# 0.72-11 {7-14 DAYS}0,87-6.15 (7 DAYS - 2 MONTHS)
# 0.55-6.7 (2-12 MONTHS)
# Pregnancy reference range:
# 1st trimester: 0.6-3.4mlU/ mL.
# 2nd trimester: 0.37-3.6mIU/ mL
# 3rd trimester: 0.38~4.04mIU/ mL
# GLUCOSE (FASTING) 5.3 mmol/L 4.1-5.6
# Prediabetes Criteria:
# (FG:
# Fasting: 5.6 - 6.9 mmoUL
# UREA 42 mmol/L 3.2 - 8.2
# 0-30 DAYS: 1.4 - 4.3 mmol/L
# 31 - 365 DAYS: 1.8-6.4 mmol/L
# 1-18 YEARS: 1.8 «6.4 mmol/L
# Pregnant women:1,8-7,0 mmol/.
# Adult (19 - 120 YEARS): 3.2 - 8.2 mmol/L
# CREATININE 99.00 pmol/L. 65 - 104
# CHOLESTEROL 6.9 mmol/L H <= 5.18
# Low-risk levels (Desirable): < 5.18 mmol/L
# Moderate-risk levels (Borderline); 5.18 - 6.19 mmol/L
# High-risk levels: >= 6.22 mmol/L
# TRIGLYCERIDES 1.9 mmol/L H 1-17
# Borderline high: t.70 - 2.25 mmol/LHigh: 2.26 - 5.64 mmol/L
# Very high: >= §.65 mmol, .
# HDL CHOLESTEROL 1,01 ramol/L 0.83 = 1.86
# Low (undesirable, high risk): < 1.00 mmol/L
# High (desirable; tow risk): >= 1.6 mmol/L
# LDL CHOLESTEROL 5.03 mmol/L H 17-34
# NON HDL CHOLESTEROL 5.9 mmol/L H <= 49
# PROTEIN (TOTAL) 80 git 57-82
# 0-7 days: 45-70 g/8-210days: 44-7694
# 211 - 365 days: 51-73 g/L
# 1-2 years: §6-75 g/L
# 1/3
#
# Scanned with
#
# CamScanner’:
#
#
#
# -----2---
#
#  “ory Suivices
#
# NUMBER : 680126554
# TE OF BIRTH =: 18/01/1968
# AGE/GENDER —: 57 Years / MALE
# NATIONALITY —: Indian
# CENTRE : BBK HIOD HC (BKH)
# LAB ID : 25390019332
# . DIAGNOSIS:
# Tost
# BIOCHEMISTRY
# PROTEIN (TOTAL)
# ALBUMIN
# GLOBULIN
# BILIRUBIN (TOTAL)
# ALKALINE PHOSPHATASE
#
# ALANINE AMINOTRANSFERASE
# G-GLUTAMYL TRANSFERASE
# ICTERUS
#
# LIPEMIA
#
# HEMOGLOBIN A1C
#
# KIDNEY FUNCTION TEST
#
# ESTIMATED GLOMERULAR FILTRATION RATE
#
# KIDNEY FUNCTION TEST
# URIC ACID
#
# KIDNEY FUNCTION TEST
# SODIUM
#
# we
#
# : DHANESH VANIYAM VEETIL PAVITHRAN
#
# Agraall JS ja) bys)
#
# REQUEST DATE: 25/03/2025 (18:35)
# PHYSICIAN ; () MOHAMED ABU ALQASSIM
# REQUEST REASON : HTN AND DLP
# LOCATION : GP COVERAGE (BKHPRIGPC)
#
# ORIGIN : BBK HIDD HC
# VALIDATION DATE _ : 14/05/2025 (08:03)
# Result Unit Flag REF. RANGES
# 3-120 years: 57-82 gf.
# 47 gil. 35-52
# 33 gf H 15-30
# 19 pmol/L 5-21
# 66 Un 56-116
# 36 UL 10-49
# 33 U/L <= 73
# 0
# 0
# 39 mmot/mol 29-42
#
# Degree of glycemic control
# Within reference range:
# 29 - 42 mmol/mof
# Excellent:
# 44-53 mmol/mot
# Meet the ADA goal <53 mmol/mal
# Good:
# 64 - 60 mmol/mol
# Poor:
# —> 64 mmol/mol
# Therapeutic action is suggested
# Suitable for diagnosis of diabetes mellitus:
# > 48 mmol/mol
# Prediabetes Criteria:
# 39 - 47 mmol/mol
#
# Moderate impairment 30 - 59
# Severe impairment 15 - 29
# Renal failure < 15
#
# 67) mUmin/1,73m4*2
#
# For African American, multiply by factor 1.212 / This calculation is not valid For persons under
#
# 19 years of age, different equation must be used.
#
# 423 pmol/L
#
# 139 mmol/L
#
# Preg: 128-148 mmol/L
# Normal: 136 - 145 mmol/L,
#
# Critical value:
#
# 220 - 547
#
# 136 - 145
#
# 213
#
# Scanned with
# : @ camScanner’:
#
#
# -----3---
#
#  Opn Aiken
#
# ems)
# 4A Ayes Agen
# Ayrsal 3S aN 501
# : DHANESH VANIYAM VEETIL PAVITHRAN
# + 680126554 REQUEST DATE : 25/03/2025 (18:35)
# : 18/01/1968 PHYSICIAN : () MOHAMED ABU ALOASSIM
# : 87 Years / MALE REQUEST REASON : HTN AND OLP
# : Indian LOCATION : GP COVERAGE (BKHPRIGPC)
# : BBK HIDD HC (BKH) ORIGIN =: BBK HIDD HC
# 2 25390019332 VALIDATION DATE _ : 14/05/2025 (08:03)
# DIAGNOSIS
# Test Result Unit Flag___ REF. RANGES
# BIOCHEMISTRY
# KIDNEY FUNCTION TEST
# SODIUM
# <1 year: < 125 / of more than > 150
# 1 - 120 Years: < 120 / or more than > 160
# POTASSIUM 5.0 mmolL. 35-54
# Serum: 3.5 - 5.1 mmol/L
# Plasma: 3.4 - 4.5 mmol/L
# Critical value:
# 0 - 4 days: < 2.8 / or mora than > 6.5
# 1-120 years: <2.8 - >6.2
# CHLORIDE 103 mmol/L 98 - 107
# BICARBONATE 26 mmol. 20-31
# KIDNEY FUNCTION TEST
# HEMOLYSIS °
# VITAMIN B12 238.0 pmol 186 - 672
# Validated by:+SEHA VALIDATION (SMC) - 14/05/2025 (07:55)
# MIRZA AMER AL! BAIG - 14/05/2025 (08:03)
# Remarks:
# AUTOVALIDATION, MIRZA AMER ALI BAIG
# Printed by: +HAJAR YAQOOB SALEM ALSHOMELI at 29/05/2025 (12:50)
# Reprinted by: BBK HIDD HC (HAJAR YAQOOB SALEM A) at 29/05/2025 (12:57) 313

# %%
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate

# %%
llm = ChatGroq(
    model = "llama3-70b-8192",
    temperature=0,
    api_key="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"
)

extract_prompt =
